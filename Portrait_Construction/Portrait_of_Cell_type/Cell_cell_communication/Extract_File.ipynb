# %%
library(CellChat)
library(ggplot2)
library(ggalluvial)
library(svglite)
library(Seurat)
library(mindr)
options(stringsAsFactors = FALSE)
library(rjson)

# %% [markdown]
# # Adult

# %% [markdown]
# ## Heatmap

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/LV.rds")
# Out:
# Warning message in gzfile(file, "rb"):
# “cannot open compressed file '/stor/public/chenyx/HHCAd/CellChat_result/LV.rds', probable reason 'No such file or directory'”
# Error in gzfile(file, "rb"): cannot open the connection
# Traceback:
#
# 1. readRDS("/stor/public/chenyx/HHCAd/CellChat_result/LV.rds")
# 2. gzfile(file, "rb")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:9){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Adult.Result/Heatmap/LV/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/RV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:9){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Adult.Result/Heatmap/RV/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/IVS.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:9){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Adult.Result/Heatmap/IVS/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/LA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:9){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Adult.Result/Heatmap/LA/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/RA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:9){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Adult.Result/Heatmap/RA/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/IAS.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:9){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Adult.Result/Heatmap/IAS/",levels(cellchat@idents)[i],".csv"))
}

# %% [markdown]
# ## ChordPlot

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/LV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Adult.Result/Chordplot//LV/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/IVS.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Adult.Result/Chordplot//IVS/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/RV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Adult.Result/Chordplot//RV/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/LA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Adult.Result/Chordplot//LA/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/IAS.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Adult.Result/Chordplot//IAS/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result/RA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Adult.Result/Chordplot//RA/",pathways[i],".csv"))
}

# %% [markdown]
# # Fetal

# %% [markdown]
# ## Heatmap

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/LV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/LV/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/IVS.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/IVS/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/RV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/RV/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/LA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/LA/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/RA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/RA/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/AO.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/AO/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/PA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/PA/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/MV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/MV/",levels(cellchat@idents)[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal/TV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:dim(ps_list)[1]){
    df <- data.frame(ps_list[i,,])
    row.names(df) <- levels(cellchat@idents)
    colnames(df) <- pathways
    write.csv(df,paste0("Fetal.Result/Heatmap/TV/",levels(cellchat@idents)[i],".csv"))
}

# %% [markdown]
# ## ChordPlot

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//LV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//LV/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//IVS.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//IVS/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//RV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//RV/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//LA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//LA/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//RA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//RA/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//AO.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//AO/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//PA.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//PA/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//MV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//MV/",pathways[i],".csv"))
}

# %%
cellchat<- readRDS("/stor/public/chenyx/HHCAd/CellChat_result_fetal//TV.rds")

# %%
pathways <- cellchat@netP$pathways
ps_list <- array(0,dim = c(length(levels(cellchat@idents)),length(levels(cellchat@idents)),length(pathways)))
for(p in 1:length(pathways)){
    pathway <- pathways[p]

    ############ From https://github.com/sqjin/CellChat/blob/master/R/visualization.R 188-223
    signaling <- pathway
    pairLR <- searchPair(signaling = pathway, pairLR.use = cellchat@LR$LRsig, key = "pathway_name", matching.exact = T, pair.only = T)
    signaling.name <- signaling
    net <- cellchat@net

    pairLR.use.name <- dimnames(net$prob)[[3]]
    pairLR.name <- intersect(rownames(pairLR), pairLR.use.name)
    pairLR <- pairLR[pairLR.name, ]
    prob <- net$prob
    pval <- net$pval

    prob[pval > 0.05] <- 0
    if (length(pairLR.name) > 1) {
    pairLR.name.use <- pairLR.name[apply(prob[,,pairLR.name], 3, sum) != 0]
    } else {
    pairLR.name.use <- pairLR.name[sum(prob[,,pairLR.name]) != 0]
    }


    if (length(pairLR.name.use) == 0) {
    stop(paste0('There is no significant communication of ', signaling.name))
    } else {
    pairLR <- pairLR[pairLR.name.use,]
    }
    nRow <- length(pairLR.name.use)

    prob <- prob[,,pairLR.name.use]
    pval <- pval[,,pairLR.name.use]

    if (length(dim(prob)) == 2) {
    prob <- replicate(1, prob, simplify="array")
    pval <- replicate(1, pval, simplify="array")
    }
    prob <-(prob-min(prob))/(max(prob)-min(prob))
    prob.sum <- apply(prob, c(1,2), sum)
    prob.sum <-(prob.sum-min(prob.sum))/(max(prob.sum)-min(prob.sum))*10 # 参数待定
    prob.sum <- signif(prob.sum,3)
    ############
    
    ps_list[,,p]<- prob.sum
    ############
}

# %%
for(i in 1:length(pathways)) {
    df <- ps_list[,,i]
    row.names(df)  <- levels(cellchat@idents)
    colnames(df) <- levels(cellchat@idents)
    write.csv(df,paste0("Fetal.Result//Chordplot//TV/",pathways[i],".csv"))
}
