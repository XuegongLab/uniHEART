# %%
library(Seurat)
library(WGCNA)
library(igraph)
library(ggplot2)
library(pheatmap)
# Out:
# Attaching SeuratObject
#
# Loading required package: dynamicTreeCut
#
# Loading required package: fastcluster
#
#
# Attaching package: ‘fastcluster’
#
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
#
#
# Attaching package: ‘WGCNA’
#
#
# The following object is masked from ‘package:stats’:
#
#     cor
#
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
as_matrix <- function(mat){
  
  tmp <- matrix(data=0L, nrow = mat@Dim[1], ncol = mat@Dim[2])
  
  row_pos <- mat@i+1
  col_pos <- findInterval(seq(mat@x)-1,mat@p[-1])+1
  val <- mat@x
  
  for (i in seq_along(val)){
    tmp[row_pos[i],col_pos[i]] <- val[i]
  }
  
  row.names(tmp) <- mat@Dimnames[[1]]
  colnames(tmp) <- mat@Dimnames[[2]]
  return(tmp)
}

# %%
dataobj<- readRDS('/data1//chenyx//HHCAd//unit_organized_fetal/Right atria.rds')

# %%
table(dataobj$cell_type)
# Out:
# Cardiomyocyte cell   Endothelial cell    Epithelial cell         Fibroblast
#                436                120                  7                204
#         Lymphocyte          Mast cell          Myelocyte                 NA
#                 11                 15                 32                  1
# Smooth muscle cell
#                  9

# %% [markdown]
# # CM

# %%
ct = "Cardiomyocyte cell"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 2072  436

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 372 genes from module 1 because their KME is too low.
#      ..removing 1 genes from module 2 because their KME is too low.
#      ..removing 2 genes from module 3 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown      grey turquoise    yellow
#       127        19       375      1541        10

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RA/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # Fb

# %%
ct = "Fibroblast"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 3195  204

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 601 genes from module 1 because their KME is too low.
#      ..removing 532 genes from module 2 because their KME is too low.
#      ..removing 3 genes from module 4 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown      grey turquoise    yellow
#       466       246      1136      1262        85

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RA/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # EC

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 3195  204

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 601 genes from module 1 because their KME is too low.
#      ..removing 532 genes from module 2 because their KME is too low.
#      ..removing 3 genes from module 4 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown      grey turquoise    yellow
#       466       246      1136      1262        85

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RA/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # Myelo

# %%
ct = "Myelocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 2963   32

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 277 genes from module 1 because their KME is too low.
#      ..removing 116 genes from module 2 because their KME is too low.
#      ..removing 16 genes from module 3 because their KME is too low.
#      ..removing 44 genes from module 4 because their KME is too low.
#      ..removing 32 genes from module 5 because their KME is too low.
#      ..removing 7 genes from module 6 because their KME is too low.
#      ..removing 24 genes from module 7 because their KME is too low.
#      ..removing 19 genes from module 9 because their KME is too low.
#      ..removing 9 genes from module 10 because their KME is too low.
#      ..removing 3 genes from module 11 because their KME is too low.
#      ..removing 2 genes from module 12 because their KME is too low.
#      ..removing 2 genes from module 13 because their KME is too low.
#      ..removing 4 genes from module 16 because their KME is too low.
#      ..removing 3 genes from module 17 because their KME is too low.
#      ..removing 4 genes from module 18 because their KME is too low.
#      ..removing 1 genes from module 19 because their KME is too low.
#      ..removing 1 genes from module 21 because their KME is too low.
#      ..removing 3 genes from module 22 because their KME is too low.
#      ..removing 5 genes from module 25 because their KME is too low.
#      ..removing 1 genes from module 29 because their KME is too low.
#      ..removing 1 genes from module 30 because their KME is too low.
#      ..removing 1 genes from module 33 because their KME is too low.
#      ..removing 1 genes from module 36 because their KME is too low.
#      ..removing 1 genes from module 39 because their KME is too low.
#      ..removing 1 genes from module 42 because their KME is too low.
#      ..removing 1 genes from module 49 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#   antiquewhite4         bisque4           black            blue           brown
#              11              16              76             209             161
#          brown4          coral1          coral2            cyan       darkgreen
#              16              11              10              40              29
#        darkgrey     darkmagenta  darkolivegreen      darkorange     darkorange2
#              26              19              20              24              16
#         darkred   darkseagreen4   darkslateblue   darkturquoise     floralwhite
#              30              12              15              28              16
#           green     greenyellow            grey          grey60       honeydew1
#             101              42             613              32              12
#           ivory  lavenderblush3      lightcoral       lightcyan      lightcyan1
#              17              12              10              34              17
#      lightgreen      lightpink4  lightsteelblue lightsteelblue1     lightyellow
#              32              13              10              17              31
#         magenta          maroon    mediumorchid   mediumpurple2   mediumpurple3
#              52              13              10              10              17
#    midnightblue    navajowhite2          orange      orangered3      orangered4
#              38              14              24              10              17
#   paleturquoise  palevioletred3            pink            plum           plum1
#              20              14              64              10              18
#           plum2          purple             red       royalblue     saddlebrown
#              15              43              89              31              21
#          salmon         salmon4         sienna3         skyblue        skyblue1
#              41              14              19              22              10
#        skyblue2        skyblue3       steelblue             tan        thistle1
#              10              19              20              42              14
#        thistle2       turquoise          violet           white          yellow
#              15             253              20              23             104
#         yellow4     yellowgreen
#              10              19

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RA/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # SMC

# %%
ct = "Smooth muscle cell"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 1882    9

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 6 genes from module 59 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#   antiquewhite2   antiquewhite4         bisque4           black            blue
#              10              16              19              32              43
#           blue2           brown          brown2          brown4           coral
#              13              38              13              19              10
#          coral1          coral2          coral3            cyan       darkgreen
#              16              16              10              29              26
#        darkgrey     darkmagenta  darkolivegreen darkolivegreen4      darkorange
#              24              21              21              13              23
#     darkorange2         darkred   darkseagreen3   darkseagreen4   darkslateblue
#              19              26              10              17              18
#   darkturquoise      darkviolet      firebrick4     floralwhite           green
#              25              13              14              19              33
#     greenyellow            grey          grey60        honeydew       honeydew1
#              31              22              27              11              17
#      indianred4           ivory  lavenderblush2  lavenderblush3      lightcoral
#              14              19              11              17              14
#       lightcyan      lightcyan1      lightgreen      lightpink3      lightpink4
#              27              20              26              11              17
#  lightsteelblue lightsteelblue1     lightyellow         magenta        magenta4
#              14              20              26              32              11
#          maroon    mediumorchid   mediumpurple2   mediumpurple3   mediumpurple4
#              17              16              14              20              10
#    midnightblue    navajowhite1    navajowhite2          orange      orangered3
#              28              11              17              24              15
#      orangered4   paleturquoise  palevioletred2  palevioletred3            pink
#              20              22              12              18              32
#            plum           plum1           plum2           plum3          purple
#              15              20              18              13              32
#             red       royalblue     saddlebrown          salmon         salmon2
#              33              26              22              29              12
#         salmon4         sienna3         skyblue        skyblue1        skyblue2
#              18              21              23              16              16
#        skyblue3       steelblue             tan         thistle        thistle1
#              20              22              31              12              18
#        thistle2        thistle3       turquoise          violet           white
#              18              12              48              22              23
#          yellow         yellow4     yellowgreen
#              37              16              20

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RA/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # Lympho

# %%
ct = "Lymphocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 2337   11

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 3 genes from module 1 because their KME is too low.
#      ..removing 1 genes from module 2 because their KME is too low.
#      ..removing 9 genes from module 3 because their KME is too low.
#      ..removing 1 genes from module 6 because their KME is too low.
#      ..removing 1 genes from module 10 because their KME is too low.
#      ..removing 2 genes from module 22 because their KME is too low.
#      ..removing 1 genes from module 24 because their KME is too low.
#      ..removing 1 genes from module 32 because their KME is too low.
#      ..removing 1 genes from module 36 because their KME is too low.
#      ..removing 1 genes from module 38 because their KME is too low.
#      ..removing 1 genes from module 41 because their KME is too low.
#      ..removing 1 genes from module 50 because their KME is too low.
#      ..removing 2 genes from module 55 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#   antiquewhite2   antiquewhite4         bisque4           black            blue
#              12              17              20              45              66
#           blue2      blueviolet           brown          brown2          brown4
#              13              10              64              14              21
#           coral          coral1          coral2          coral3            cyan
#              12              17              16              11              33
#       darkgreen        darkgrey     darkmagenta  darkolivegreen darkolivegreen2
#              29              28              25              25              10
# darkolivegreen4      darkorange     darkorange2         darkred   darkseagreen3
#              14              27              21              29              12
#   darkseagreen4   darkslateblue   darkturquoise      darkviolet      firebrick3
#              17              20              28              13              10
#      firebrick4     floralwhite           green     greenyellow            grey
#              14              21              58              34              25
#          grey60        honeydew       honeydew1      indianred3      indianred4
#              32              12              18              10              14
#           ivory  lavenderblush2  lavenderblush3      lightblue4      lightcoral
#              21              12              18              10              14
#       lightcyan      lightcyan1      lightgreen      lightpink3      lightpink4
#              33              21              31              12              18
#  lightslateblue  lightsteelblue lightsteelblue1     lightyellow         magenta
#              10              15              21              30              44
#        magenta4          maroon    mediumorchid   mediumpurple1   mediumpurple2
#              12              18              16              11              15
#   mediumpurple3   mediumpurple4    midnightblue    navajowhite1    navajowhite2
#              21              11              33              12              18
#          orange      orangered1      orangered3      orangered4   paleturquoise
#              27              11              15              21              25
#  palevioletred2  palevioletred3            pink           pink4            plum
#              13              19              44              11              16
#           plum1           plum2           plum3          purple             red
#              22              20              13              36              48
#       royalblue     saddlebrown          salmon         salmon2         salmon4
#              29              26              34              13              19
#         sienna3         sienna4         skyblue        skyblue1        skyblue2
#              23              11              26              16              16
#        skyblue3        skyblue4       steelblue             tan         thistle
#              22              11              26              34              13
#        thistle1        thistle2        thistle3       turquoise          violet
#              19              19              13              73              25
#           white          yellow         yellow3         yellow4     yellowgreen
#              26              58              11              16              23

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RA/',ct,'.',i,'.csv'))
        i = i + 1
    }
}
