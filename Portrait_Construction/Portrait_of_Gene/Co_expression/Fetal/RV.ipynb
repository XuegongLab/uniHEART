# %%
library(Seurat)
library(WGCNA)
library(igraph)
library(ggplot2)
library(pheatmap)
# Out:
# Attaching SeuratObject
#
# Loading required package: dynamicTreeCut
#
# Loading required package: fastcluster
#
#
# Attaching package: ‘fastcluster’
#
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
#
#
# Attaching package: ‘WGCNA’
#
#
# The following object is masked from ‘package:stats’:
#
#     cor
#
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
as_matrix <- function(mat){
  
  tmp <- matrix(data=0L, nrow = mat@Dim[1], ncol = mat@Dim[2])
  
  row_pos <- mat@i+1
  col_pos <- findInterval(seq(mat@x)-1,mat@p[-1])+1
  val <- mat@x
  
  for (i in seq_along(val)){
    tmp[row_pos[i],col_pos[i]] <- val[i]
  }
  
  row.names(tmp) <- mat@Dimnames[[1]]
  colnames(tmp) <- mat@Dimnames[[2]]
  return(tmp)
}

# %%
dataobj<- readRDS('/data1//chenyx//HHCAd//unit_organized_fetal/Right ventricle.rds')

# %%
table(dataobj$cell_type)
# Out:
# Cardiomyocyte cell   Endothelial cell         Fibroblast         Lymphocyte
#                341                 69                262                  8
#          Mast cell          Myelocyte                 NA Smooth muscle cell
#                  7                 41                 19                  1

# %% [markdown]
# # CM

# %%
ct = "Cardiomyocyte cell"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 2173  341

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 136 genes from module 1 because their KME is too low.
#      ..removing 32 genes from module 2 because their KME is too low.
#      ..removing 4 genes from module 4 because their KME is too low.
#      ..removing 2 genes from module 5 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown     green      grey turquoise    yellow
#       561       194        15       174      1074       155

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RV/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # Fb

# %%
ct = "Fibroblast"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 2696  262

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 1011 genes from module 1 because their KME is too low.
#      ..removing 250 genes from module 2 because their KME is too low.
#      ..removing 79 genes from module 3 because their KME is too low.
#      ..removing 17 genes from module 4 because their KME is too low.
#      ..removing 1 genes from module 6 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown     green      grey turquoise    yellow
#       162        40        15      1358      1091        30

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RV/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # EC

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 2696  262

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 1011 genes from module 1 because their KME is too low.
#      ..removing 250 genes from module 2 because their KME is too low.
#      ..removing 79 genes from module 3 because their KME is too low.
#      ..removing 17 genes from module 4 because their KME is too low.
#      ..removing 1 genes from module 6 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown     green      grey turquoise    yellow
#       162        40        15      1358      1091        30

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RV/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # Myelo

# %%
ct = "Myelocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 3394   41

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 1664 genes from module 1 because their KME is too low.
#      ..removing 3 genes from module 2 because their KME is too low.
#      ..removing 19 genes from module 3 because their KME is too low.
#      ..removing 1 genes from module 4 because their KME is too low.
#      ..removing 1 genes from module 5 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#      blue     brown     green      grey       red turquoise    yellow
#       131       103        32      1688        22      1335        83

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RV/',ct,'.',i,'.csv'))
        i = i + 1
    }
}

# %% [markdown]
# # Lympho

# %%
ct = "Lymphocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 3148    8

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 2 genes from module 1 because their KME is too low.
#      ..removing 2 genes from module 2 because their KME is too low.
#      ..removing 82 genes from module 5 because their KME is too low.
#      ..removing 1 genes from module 6 because their KME is too low.
#      ..removing 1 genes from module 7 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
colors <- table(net$colors)
colors
# Out:
#   antiquewhite4         bisque4           black            blue           brown
#              11              20             110             174             163
#          brown4          coral1          coral2            cyan       darkgreen
#              22              11              10              56              43
#        darkgrey     darkmagenta  darkolivegreen      darkorange     darkorange2
#              42              35              36              41              23
#         darkred   darkseagreen4   darkslateblue   darkturquoise     floralwhite
#              44              11              19              43              28
#           green     greenyellow            grey          grey60       honeydew1
#             132              57              88              46              13
#           ivory  lavenderblush3       lightcyan      lightcyan1      lightgreen
#              28              13              48              28              46
#      lightpink4 lightsteelblue1     lightyellow         magenta          maroon
#              14              30              45              61              14
#    mediumorchid   mediumpurple3    midnightblue    navajowhite2          orange
#              10              31              56              15              42
#      orangered4   paleturquoise  palevioletred3            pink           plum1
#              33              37              17              81              33
#           plum2          purple             red       royalblue     saddlebrown
#              18              59             111              44              40
#          salmon         salmon4         sienna3         skyblue        skyblue2
#              56              17              34              40              10
#        skyblue3       steelblue             tan        thistle1        thistle2
#              34              40              57              18              18
#       turquoise          violet           white          yellow     yellowgreen
#             323              37              41             157              34

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
i = 1
for (c in names(colors)){
    googene <- colnames(datExpr_filted)[net$colors == c]
    TOMp <- TOM[googene,googene]
    df_ct=TOMp
    df_ct <- df_ct -diag(dim(df_ct)[1])
    if(dim(df_ct)[1]>=2){
        write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Fetal/','RV/',ct,'.',i,'.csv'))
        i = i + 1
    }
}
