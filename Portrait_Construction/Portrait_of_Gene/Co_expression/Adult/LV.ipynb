# %%
library(Seurat)
library(WGCNA)
library(igraph)
library(ggplot2)
library(pheatmap)
# Out:
# Attaching SeuratObject
#
# Loading required package: dynamicTreeCut
#
# Loading required package: fastcluster
#
#
# Attaching package: ‘fastcluster’
#
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
#
#
# Attaching package: ‘WGCNA’
#
#
# The following object is masked from ‘package:stats’:
#
#     cor
#
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
as_matrix <- function(mat){
  
  tmp <- matrix(data=0L, nrow = mat@Dim[1], ncol = mat@Dim[2])
  
  row_pos <- mat@i+1
  col_pos <- findInterval(seq(mat@x)-1,mat@p[-1])+1
  val <- mat@x
  
  for (i in seq_along(val)){
    tmp[row_pos[i],col_pos[i]] <- val[i]
  }
  
  row.names(tmp) <- mat@Dimnames[[1]]
  colnames(tmp) <- mat@Dimnames[[2]]
  return(tmp)
}

# %%
dataobj<- readRDS('/data1//chenyx//HHCAd//unit_organized/LV.seuratobj.rds')

# %%
table(dataobj$cell_type)
# Out:
#                Adipocyte       Cardiomyocyte cell         Endothelial cell
#                      761                    64497                    16756
#               Fibroblast               Lymphocyte                Mast cell
#                    27519                     1192                       19
#                Myelocyte                   Neuron Neutrophilic granulocyte
#                     8389                     1100                      194
#                 Pericyte       Smooth muscle cell
#                    10805                     2275

# %% [markdown]
# # CM

# %%
ct = "Cardiomyocyte cell"

# %%
cm.sample <- subset(dataobj,cell_type==ct,downsample=10000,seed=1234)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]   326 22014

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 81 genes from module 1 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#      mergeCloseModules: less than two proper modules.
#       ..color levels are grey, turquoise
#       ..there is nothing to merge.
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      grey turquoise
#        81       245

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # Fb

# %%
ct = "Fibroblast"

# %%
cm.sample <- subset(dataobj,cell_type==ct,downsample=10000,seed=1234)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]   111 20534

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 12 genes from module 1 because their KME is too low.
#      ..removing 3 genes from module 2 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      blue      grey turquoise
#        15        15        81

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.1.csv'))

# %%
googene <- colnames(datExpr_filted)[net$colors == "blue"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.2.csv'))

# %% [markdown]
# # EC

# %%
ct = "Endothelial cell"

# %%
cm.sample <- subset(dataobj,cell_type==ct,downsample=10000,seed=1234)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]    56 16756

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 12 genes from module 1 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#      mergeCloseModules: less than two proper modules.
#       ..color levels are grey, turquoise
#       ..there is nothing to merge.
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      grey turquoise
#        12        44

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # Myelo

# %%
ct = "Myelocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct,downsample=10000,seed=1234)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]   58 8389

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 9 genes from module 1 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#      mergeCloseModules: less than two proper modules.
#       ..color levels are grey, turquoise
#       ..there is nothing to merge.
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      grey turquoise
#         9        49

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # Peri

# %%
ct = "Pericyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct,downsample=10000,seed=1234)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]    73 10805

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 22 genes from module 1 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#      mergeCloseModules: less than two proper modules.
#       ..color levels are grey, turquoise
#       ..there is nothing to merge.
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      grey turquoise
#        22        51

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # SMC

# %%
ct = "Smooth muscle cell"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]   51 2275

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 15 genes from module 1 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#      mergeCloseModules: less than two proper modules.
#       ..color levels are grey, turquoise
#       ..there is nothing to merge.
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      grey turquoise
#        15        36

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # Neuron

# %%
ct = "Neuron"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]   49 1100

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#  No significant modules detected in block 1
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
# Warning message in blockwiseModules(datExpr_filted, power = 5, corType = "bicor", :
# “blockwiseModules: mergeCloseModules failed with the following error message:
#      Error in mergeCloseModules(datExpr, colors[gsg$goodGenes], cutHeight = mergeCutHeight,  :
#   Error in moduleEigengenes(expr = exprData[[set]]$data, colors = setColors,  :
#   Color levels are empty. Possible reason: the only color is grey and grey module is excluded from the calculation.
#
#
# --> returning unmerged colors.
# ”

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Warning message in pmin(objHeights[dendro$order][floor(positions)], objHeights[dendro$order][ceiling(positions)]):
# “an argument will be fractionally recycled”
# Plot with title “”

# %%
table(net$colors)
# Out:
# grey
#   49

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "grey"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # Lympho

# %%
ct = "Lymphocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1]   13 1192

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 2 genes from module 1 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#      mergeCloseModules: less than two proper modules.
#       ..color levels are grey, turquoise
#       ..there is nothing to merge.
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Warning message in pmin(objHeights[dendro$order][floor(positions)], objHeights[dendro$order][ceiling(positions)]):
# “an argument will be fractionally recycled”
# Plot with title “”

# %%
table(net$colors)
# Out:
#      grey turquoise
#         2        11

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.csv'))

# %% [markdown]
# # Adipocyte

# %%
ct = "Adipocyte"

# %%
cm.sample <- subset(dataobj,cell_type==ct)
df <- cm.sample@assays$RNA@data[rowSums(cm.sample)>0,]

# %%
df <- df[apply(df,1,mad)>0,]

# %%
dim(df)
# Out:
# [1] 799 761

# %%
df = as.matrix(df)
datExpr_filted <- t(df)
gsg = goodSamplesGenes(datExpr_filted, verbose = 3)
gsg$allOK
sampleTree = hclust(dist(datExpr_filted), method = "average")
plot(sampleTree, main = "Sample clustering to detect outliers", sub="", xlab="")
# Out:
#  Flagging genes and samples with too many missing values...
#   ..step 1
# [1] TRUE
# Plot with title “Sample clustering to detect outliers”

# %%
net <- blockwiseModules(datExpr_filted, power = 5,
  corType = "bicor", # use robust correlation
networkType = "signed", minModuleSize = 10,
reassignThreshold = 0, mergeCutHeight = 0.15, 
numericLabels = F, pamRespectsDendro = FALSE,saveTOMs=T,TOMType='signed',
verbose = 3)
# Out:
#  Calculating module eigengenes block-wise from all genes
#    Flagging genes and samples with too many missing values...
#     ..step 1
#  ..Working on block 1 .
#     TOM calculation: adjacency..
#     ..will not use multithreading.
#      Fraction of slow calculations: 0.000000
#     ..connectivity..
#     ..matrix multiplication (system BLAS)..
#     ..normalization..
#     ..done.
#    ..saving TOM for block 1 into file blockwiseTOM-block.1.RData
#  ....clustering..
#  ....detecting modules..
#  ....calculating module eigengenes..
#  ....checking kME in modules..
#      ..removing 30 genes from module 1 because their KME is too low.
#      ..removing 3 genes from module 2 because their KME is too low.
#  ..merging modules that are too close..
#      mergeCloseModules: Merging modules whose distance is less than 0.15
#        Calculating new MEs...

# %%
options(repr.plot.width=6, repr.plot.height=6)
geneTree = net$dendrograms[[1]]
moduleColors = labels2colors(net$colors)
TOM <- TOMsimilarityFromExpr(datExpr_filted, power = 5,TOMType = 'signed',corType = "bicor", networkType = "signed")
dissTOM = 1 - TOM
plotTOM = dissTOM ^ 5
diag(plotTOM) = NA
TOMplot(
  plotTOM,
  geneTree,
  moduleColors,
  main = "Network heatmap plot, all genes"
)
# Out:
# TOM calculation: adjacency..
# ..will not use multithreading.
#  Fraction of slow calculations: 0.000000
# ..connectivity..
# ..matrix multiplication (system BLAS)..
# ..normalization..
# ..done.
# Plot with title “Network heatmap plot, all genes”

# %%
# Convert labels to colors for plotting
mergedColors = net$colors
# Plot the dendrogram and the module colors underneath
plotDendroAndColors(net$dendrograms[[1]], mergedColors[net$blockGenes[[1]]],
"Module colors",
dendroLabels = FALSE, hang = 0.03,
addGuide = TRUE, guideHang = 0.05)
# Out:
# Plot with title “”

# %%
table(net$colors)
# Out:
#      blue     brown      grey turquoise
#       127        36        33       603

# %%
rownames(TOM) <- colnames(datExpr_filted)
colnames(TOM) <- colnames(datExpr_filted)

# %%
googene <- colnames(datExpr_filted)[net$colors == "turquoise"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.1.csv'))

# %%
googene <- colnames(datExpr_filted)[net$colors == "blue"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.2.csv'))

# %%
googene <- colnames(datExpr_filted)[net$colors == "brown"]
TOMp <- TOM[googene,googene]
df_ct=TOMp
df_ct <- df_ct -diag(dim(df_ct)[1])

# %%
write.csv(df_ct,paste0('/data1/chenyx/HHCAd/coexpression/Adult/','LV/',ct,'.3.csv'))
